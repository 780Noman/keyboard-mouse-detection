# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Keyboard_and_mouse_dectection.v1i.yolov8
# Out:
# /content/drive/MyDrive/Keyboard_and_mouse_dectection.v1i.yolov8

# %%
# %cd /content/drive/MyDrive/Keyboard_and_mouse_dectection.v1i.yolov8

# !yolo task=detect mode=train model=yolov8s.pt data= /content/drive/MyDrive/Keyboard_and_mouse_dectection.v1i.yolov8/data.yaml epochs=25 imgsz=224 plots=True
# Out:
# /content/drive/MyDrive/Keyboard_and_mouse_dectection.v1i.yolov8
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls runs/detect/train/
# Out:
# args.yaml					    R_curve.png		train_batch107.jpg
# confusion_matrix.png				    results.csv		train_batch1.jpg
# events.out.tfevents.1706795450.f57bb77d45f6.2083.0  results.png		train_batch2.jpg
# F1_curve.png					    train_batch0.jpg	val_batch0_labels.jpg
# P_curve.png					    train_batch105.jpg	val_batch0_pred.jpg
# PR_curve.png					    train_batch106.jpg	weights

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
Image(filename='runs/detect/train/confusion_matrix.png', width=900)

# %%
Image(filename='runs/detect/train/train_batch0.jpg', width=800)

# %%
Image(filename='runs/detect/train/val_batch0_pred.jpg', width=800)

# %%
# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data=/content/drive/MyDrive/Keyboard_and_mouse_dectection.v1i.yolov8/data.yaml
# Out:
# 2024-02-01 14:57:27.866311: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-01 14:57:27.866378: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-01 14:57:27.868531: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-01 14:57:29.452302: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/Keyboard_and_mouse_dectection.v1i.yolov8/test/images save=True
# Out:
# 2024-02-01 14:59:27.357732: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-01 14:59:27.357799: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-01 14:59:27.359711: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-01 14:59:28.674018: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('/content/drive/MyDrive/Keyboard_and_mouse_dectection.v1i.yolov8/runs/detect/predict2/*.jpg')[:20]:
      display(Image(filename=image_path, width=600))
      print("\n")
